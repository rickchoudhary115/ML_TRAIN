# %% [markdown]
# <a href="https://colab.research.google.com/github/rickchoudhary115/ML_TRAIN/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Position_Salaries.csv')
X=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.tree import DecisionTreeClassifier
regressor=DecisionTreeClassifier(random_state=0)
regressor.fit(X,y)
regressor.predict([[6.5]])
# Out:
# array([150000])

# %%
X_grid=np.arange(min(X)[0],max(X)[0],0.01)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color='green')
plt.plot(X_grid,regressor.predict(X_grid),color='blue')
plt.title("truth or bluff(decision_tree)")
plt.xlabel("position")
plt.ylabel("salary")
plt.grid(True)
plt.show()
